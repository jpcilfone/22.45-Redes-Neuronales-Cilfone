# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models,Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Flatten
from tensorflow.keras.utils import to_categorical

# %%
#Preprocesamiento de la data
(x_train_0, y_train_fine), (x_test, y_test_fine) = tf.keras.datasets.cifar100.load_data(
    label_mode='fine'
)
import matplotlib.pyplot as plt

# Split the training data into training and validation sets
x_train_1, x_val, y_train, y_val = train_test_split(x_train_0, y_train_fine, test_size=0.2, random_state=42)
print("Size of x_train_1:", x_train_1.shape)
print("Size of x_val:", x_val.shape)


# Convert labels to one-hot encoding
num_classes = 100
y_train_ = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 2s 0us/step
# Size of x_train_1: (40000, 32, 32, 3)
# Size of x_val: (10000, 32, 32, 3)

# %% [markdown]
# Utilice la data augmentation pero parece que lo único que hizo fue ralentizar el proceso de entrenamiento. Para intentar mejorar un poco la data sí hice un horizontal flip, duplicando la cantidad de datos de train.

# %%
#Data Augmentation

x_train_norm=x_train_1

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1,
    shear_range=0.1
)


# Primer approach a data augmentation
x_train_flipped = np.flip(x_train_norm, axis=2)
x_train = np.concatenate((x_train_norm, x_train_flipped), axis=0)
y_train = np.concatenate((y_train_, y_train_), axis=0)

datagen.fit(x_train)
print("Size of x_train:", x_train.shape)
print("Size of y_train:", y_train.shape)
# Out:
# Size of x_train: (80000, 32, 32, 3)
# Size of y_train: (80000, 100)

# %% [markdown]
# Encontré una función de activación swish, que es muy parecida a la ReLu pero da mejores resultados
# swish(x)=x/(1+e^(-bx))

# %%
input_shape = x_train.shape[1:]  # (32, 32, 3)

model = Sequential([
    Flatten(input_shape=(32,32,3)),

    Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    BatchNormalization(),
    Dropout(0.2),
    Dense(700, activation='swish', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    BatchNormalization(),
    Dense(256, activation='swish', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    Dropout(0.25),
    Dense(100, activation='softmax')
])
# Compile the model with learning rate scheduling
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=10000,
    decay_rate=1)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Callbacks

from tensorflow.keras.callbacks import EarlyStopping,LearningRateScheduler,ModelCheckpoint,ReduceLROnPlateau, TensorBoard
from tensorflow.keras.optimizers import Adam

# Model Checkpoint
mc = ModelCheckpoint(
    "best_weights.h5",
    monitor = "val_accuracy",
    verbose = 1,
    save_best_only = True,
    save_weights_only = True,
)

# Reduce Learning Rate on Plateau
rlrop = ReduceLROnPlateau(
    monitor = "val_accuracy",
    factor = 0.5,
    patience = 10,
    verbose = 1,
    min_lr = 1e-5
)

# Early Stopping
es = EarlyStopping(
    monitor = "val_accuracy",
    patience = 20,                # Probamos con 3, 7, 10, 15, 20, 100 (sin early stopping basicamente)
    verbose = 1,
    restore_best_weights = True,
)

# Tensorboard
tb = TensorBoard(
    log_dir="logs",
)

# %%
history = model.fit(x_train, y_train, #batch_size=64),
                    batch_size=64,
                    epochs=200,
                    validation_data=(x_val, y_val),
                    callbacks=[rlrop, es, mc, tb])
# Out:
# Epoch 1/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 5.2019 - accuracy: 0.0715
# Epoch 1: val_accuracy improved from -inf to 0.09490, saving model to best_weights.h5
# 1250/1250 [==============================] - 10s 6ms/step - loss: 5.1970 - accuracy: 0.0716 - val_loss: 4.5578 - val_accuracy: 0.0949 - lr: 9.9748e-04
# Epoch 2/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 4.2354 - accuracy: 0.1113
# Epoch 2: val_accuracy did not improve from 0.09490
# 1250/1250 [==============================] - 7s 6ms/step - loss: 4.2352 - accuracy: 0.1112 - val_loss: 4.4846 - val_accuracy: 0.0808 - lr: 9.9496e-04
# Epoch 3/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 4.0350 - accuracy: 0.1211
# Epoch 3: val_accuracy improved from 0.09490 to 0.12630, saving model to best_weights.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 4.0349 - accuracy: 0.1211 - val_loss: 3.9805 - val_accuracy: 0.1263 - lr: 9.9245e-04
# Epoch 4/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 4.0866 - accuracy: 0.1184
# Epoch 4: val_accuracy did not improve from 0.12630
# 1250/1250 [==============================] - 8s 6ms/step - loss: 4.0869 - accuracy: 0.1184 - val_loss: 4.2775 - val_accuracy: 0.0905 - lr: 9.8995e-04
# Epoch 5/200
# 1245/1250 [============================>.] - ETA: 0s - loss: 4.0376 - accuracy: 0.1272
# Epoch 5: val_accuracy did not improve from 0.12630
# 1250/1250 [==============================] - 7s 5ms/step - loss: 4.0378 - accuracy: 0.1273 - val_loss: 4.4068 - val_accuracy: 0.0924 - lr: 9.8745e-04
# Epoch 6/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 4.2477 - accuracy: 0.1132
# Epoch 6: val_accuracy improved from 0.12630 to 0.12860, saving model to best_weights.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 4.2465 - accuracy: 0.1132 - val_loss: 4.0555 - val_accuracy: 0.1286 - lr: 9.8496e-04
# Epoch 7/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 3.9491 - accuracy: 0.1369
# Epoch 7: val_accuracy did not improve from 0.12860
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.9491 - accuracy: 0.1368 - val_loss: 4.4357 - val_accuracy: 0.0866 - lr: 9.8248e-04
# Epoch 8/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 4.1796 - accuracy: 0.1223
# Epoch 8: val_accuracy improved from 0.12860 to 0.13510, saving model to best_weights.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 4.1787 - accuracy: 0.1224 - val_loss: 3.9937 - val_accuracy: 0.1351 - lr: 9.8000e-04
# Epoch 9/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 4.0065 - accuracy: 0.1343
# Epoch 9: val_accuracy did not improve from 0.13510
# 1250/1250 [==============================] - 7s 6ms/step - loss: 4.0061 - accuracy: 0.1343 - val_loss: 4.0865 - val_accuracy: 0.1143 - lr: 9.7753e-04
# Epoch 10/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 4.0067 - accuracy: 0.1348
# Epoch 10: val_accuracy improved from 0.13510 to 0.14890, saving model to best_weights.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 4.0069 - accuracy: 0.1347 - val_loss: 3.9676 - val_accuracy: 0.1489 - lr: 9.7506e-04
# Epoch 11/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 3.9386 - accuracy: 0.1387
# Epoch 11: val_accuracy did not improve from 0.14890
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.9384 - accuracy: 0.1387 - val_loss: 3.8848 - val_accuracy: 0.1428 - lr: 9.7261e-04
# Epoch 12/200
# 1247/1250 [============================>.] - ETA: 0s - loss: 3.8839 - accuracy: 0.1440
# Epoch 12: val_accuracy improved from 0.14890 to 0.16110, saving model to best_weights.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.8835 - accuracy: 0.1441 - val_loss: 3.7592 - val_accuracy: 0.1611 - lr: 9.7015e-04
# Epoch 13/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 3.8917 - accuracy: 0.1423
# Epoch 13: val_accuracy did not improve from 0.16110
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.8918 - accuracy: 0.1423 - val_loss: 3.8673 - val_accuracy: 0.1461 - lr: 9.6771e-04
# Epoch 14/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 3.8521 - accuracy: 0.1502
# Epoch 14: val_accuracy did not improve from 0.16110
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.8516 - accuracy: 0.1504 - val_loss: 3.9421 - val_accuracy: 0.1320 - lr: 9.6526e-04
# Epoch 15/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 3.8627 - accuracy: 0.1480
# Epoch 15: val_accuracy did not improve from 0.16110
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.8634 - accuracy: 0.1478 - val_loss: 4.2047 - val_accuracy: 0.1103 - lr: 9.6283e-04
# Epoch 16/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 3.7897 - accuracy: 0.1584
# Epoch 16: val_accuracy did not improve from 0.16110
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.7892 - accuracy: 0.1585 - val_loss: 3.7648 - val_accuracy: 0.1584 - lr: 9.6040e-04
# Epoch 17/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 3.7731 - accuracy: 0.1586
# Epoch 17: val_accuracy did not improve from 0.16110
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.7731 - accuracy: 0.1586 - val_loss: 3.7613 - val_accuracy: 0.1610 - lr: 9.5798e-04
# Epoch 18/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 3.7422 - accuracy: 0.1627
# Epoch 18: val_accuracy improved from 0.16110 to 0.17250, saving model to best_weights.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.7423 - accuracy: 0.1627 - val_loss: 3.6956 - val_accuracy: 0.1725 - lr: 9.5556e-04
# Epoch 19/200
# 1240/1250 [============================>.] - ETA: 0s - loss: 3.7287 - accuracy: 0.1643
# Epoch 19: val_accuracy improved from 0.17250 to 0.17840, saving model to best_weights.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.7283 - accuracy: 0.1642 - val_loss: 3.6653 - val_accuracy: 0.1784 - lr: 9.5315e-04
# Epoch 20/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 3.7409 - accuracy: 0.1640
# Epoch 20: val_accuracy did not improve from 0.17840
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.7417 - accuracy: 0.1639 - val_loss: 3.9236 - val_accuracy: 0.1447 - lr: 9.5075e-04
# Epoch 21/200
# 1240/1250 [============================>.] - ETA: 0s - loss: 3.7826 - accuracy: 0.1606
# Epoch 21: val_accuracy did not improve from 0.17840
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.7814 - accuracy: 0.1609 - val_loss: 3.8188 - val_accuracy: 0.1475 - lr: 9.4835e-04
# Epoch 22/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 3.7250 - accuracy: 0.1677
# Epoch 22: val_accuracy did not improve from 0.17840
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.7248 - accuracy: 0.1677 - val_loss: 3.7476 - val_accuracy: 0.1658 - lr: 9.4596e-04
# Epoch 23/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 3.7345 - accuracy: 0.1664
# Epoch 23: val_accuracy did not improve from 0.17840
# 1250/1250 [==============================] - 6s 5ms/step - loss: 3.7351 - accuracy: 0.1665 - val_loss: 3.7562 - val_accuracy: 0.1635 - lr: 9.4357e-04
# Epoch 24/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 3.6871 - accuracy: 0.1694
# Epoch 24: val_accuracy did not improve from 0.17840
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.6869 - accuracy: 0.1694 - val_loss: 3.7543 - val_accuracy: 0.1537 - lr: 9.4119e-04
# Epoch 25/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 3.6812 - accuracy: 0.1706
# Epoch 25: val_accuracy did not improve from 0.17840
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.6813 - accuracy: 0.1705 - val_loss: 3.7022 - val_accuracy: 0.1723 - lr: 9.3882e-04
# Epoch 26/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 3.6698 - accuracy: 0.1732
# Epoch 26: val_accuracy did not improve from 0.17840
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.6698 - accuracy: 0.1732 - val_loss: 3.7542 - val_accuracy: 0.1608 - lr: 9.3645e-04
# Epoch 27/200
# 1245/1250 [============================>.] - ETA: 0s - loss: 3.6771 - accuracy: 0.1722
# Epoch 27: val_accuracy improved from 0.17840 to 0.18710, saving model to best_weights.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.6766 - accuracy: 0.1722 - val_loss: 3.5824 - val_accuracy: 0.1871 - lr: 9.3409e-04
# Epoch 28/200
# 1247/1250 [============================>.] - ETA: 0s - loss: 3.6873 - accuracy: 0.1726
# Epoch 28: val_accuracy did not improve from 0.18710
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.6870 - accuracy: 0.1726 - val_loss: 3.7593 - val_accuracy: 0.1595 - lr: 9.3173e-04
# Epoch 29/200
# 1247/1250 [============================>.] - ETA: 0s - loss: 3.6707 - accuracy: 0.1769
# Epoch 29: val_accuracy did not improve from 0.18710
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.6708 - accuracy: 0.1769 - val_loss: 3.6878 - val_accuracy: 0.1811 - lr: 9.2938e-04
# Epoch 30/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 3.6552 - accuracy: 0.1747
# Epoch 30: val_accuracy improved from 0.18710 to 0.18780, saving model to best_weights.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.6552 - accuracy: 0.1747 - val_loss: 3.6109 - val_accuracy: 0.1878 - lr: 9.2704e-04
# Epoch 31/200
# 1247/1250 [============================>.] - ETA: 0s - loss: 3.6457 - accuracy: 0.1772
# Epoch 31: val_accuracy did not improve from 0.18780
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.6459 - accuracy: 0.1771 - val_loss: 3.8822 - val_accuracy: 0.1551 - lr: 9.2470e-04
# Epoch 32/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 3.6518 - accuracy: 0.1782
# Epoch 32: val_accuracy did not improve from 0.18780
# 1250/1250 [==============================] - 6s 5ms/step - loss: 3.6521 - accuracy: 0.1780 - val_loss: 3.7140 - val_accuracy: 0.1716 - lr: 9.2237e-04
# Epoch 33/200
# 1246/1250 [============================>.] - ETA: 0s - loss: 3.6738 - accuracy: 0.1741
# Epoch 33: val_accuracy did not improve from 0.18780
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.6741 - accuracy: 0.1741 - val_loss: 3.8227 - val_accuracy: 0.1569 - lr: 9.2004e-04
# Epoch 34/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 3.6529 - accuracy: 0.1780
# Epoch 34: val_accuracy improved from 0.18780 to 0.18920, saving model to best_weights.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.6523 - accuracy: 0.1781 - val_loss: 3.5890 - val_accuracy: 0.1892 - lr: 9.1772e-04
# Epoch 35/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 3.6432 - accuracy: 0.1786
# Epoch 35: val_accuracy did not improve from 0.18920
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.6440 - accuracy: 0.1785 - val_loss: 3.7008 - val_accuracy: 0.1782 - lr: 9.1541e-04
# Epoch 36/200
# 1247/1250 [============================>.] - ETA: 0s - loss: 3.6326 - accuracy: 0.1794
# Epoch 36: val_accuracy did not improve from 0.18920
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.6325 - accuracy: 0.1794 - val_loss: 3.7355 - val_accuracy: 0.1759 - lr: 9.1310e-04
# Epoch 37/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 3.6308 - accuracy: 0.1786
# Epoch 37: val_accuracy did not improve from 0.18920
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.6309 - accuracy: 0.1787 - val_loss: 3.7227 - val_accuracy: 0.1705 - lr: 9.1080e-04
# Epoch 38/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 3.6241 - accuracy: 0.1822
# Epoch 38: val_accuracy improved from 0.18920 to 0.19850, saving model to best_weights.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.6239 - accuracy: 0.1823 - val_loss: 3.5508 - val_accuracy: 0.1985 - lr: 9.0850e-04
# Epoch 39/200
# 1250/1250 [==============================] - ETA: 0s - loss: 3.6104 - accuracy: 0.1841
# Epoch 39: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.6104 - accuracy: 0.1841 - val_loss: 3.7004 - val_accuracy: 0.1712 - lr: 9.0621e-04
# Epoch 40/200
# 1250/1250 [==============================] - ETA: 0s - loss: 3.6410 - accuracy: 0.1768
# Epoch 40: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 9s 7ms/step - loss: 3.6410 - accuracy: 0.1768 - val_loss: 3.6762 - val_accuracy: 0.1774 - lr: 9.0392e-04
# Epoch 41/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 3.6198 - accuracy: 0.1815
# Epoch 41: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.6204 - accuracy: 0.1814 - val_loss: 3.5999 - val_accuracy: 0.1902 - lr: 9.0164e-04
# Epoch 42/200
# 1241/1250 [============================>.] - ETA: 0s - loss: 3.6041 - accuracy: 0.1819
# Epoch 42: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.6041 - accuracy: 0.1819 - val_loss: 3.6938 - val_accuracy: 0.1783 - lr: 8.9937e-04
# Epoch 43/200
# 1250/1250 [==============================] - ETA: 0s - loss: 3.6107 - accuracy: 0.1816
# Epoch 43: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.6107 - accuracy: 0.1816 - val_loss: 3.7940 - val_accuracy: 0.1620 - lr: 8.9710e-04
# Epoch 44/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 3.6136 - accuracy: 0.1827
# Epoch 44: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.6138 - accuracy: 0.1827 - val_loss: 3.6630 - val_accuracy: 0.1845 - lr: 8.9484e-04
# Epoch 45/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 3.6164 - accuracy: 0.1827
# Epoch 45: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.6164 - accuracy: 0.1826 - val_loss: 3.7192 - val_accuracy: 0.1717 - lr: 8.9258e-04
# Epoch 46/200
# 1240/1250 [============================>.] - ETA: 0s - loss: 3.5985 - accuracy: 0.1838
# Epoch 46: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.5986 - accuracy: 0.1837 - val_loss: 3.6029 - val_accuracy: 0.1889 - lr: 8.9033e-04
# Epoch 47/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 3.5946 - accuracy: 0.1831
# Epoch 47: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.5949 - accuracy: 0.1831 - val_loss: 3.6233 - val_accuracy: 0.1885 - lr: 8.8808e-04
# Epoch 48/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 3.5884 - accuracy: 0.1845
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.00044292217353358865.
#
# Epoch 48: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.5882 - accuracy: 0.1845 - val_loss: 3.7237 - val_accuracy: 0.1681 - lr: 8.8584e-04
# Epoch 49/200
# 1247/1250 [============================>.] - ETA: 0s - loss: 3.6007 - accuracy: 0.1841
# Epoch 49: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.6007 - accuracy: 0.1841 - val_loss: 3.7675 - val_accuracy: 0.1667 - lr: 8.8361e-04
# Epoch 50/200
# 1242/1250 [============================>.] - ETA: 0s - loss: 3.5961 - accuracy: 0.1867
# Epoch 50: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.5964 - accuracy: 0.1867 - val_loss: 3.6066 - val_accuracy: 0.1915 - lr: 8.8138e-04
# Epoch 51/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 3.5847 - accuracy: 0.1866
# Epoch 51: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.5849 - accuracy: 0.1866 - val_loss: 3.6231 - val_accuracy: 0.1879 - lr: 8.7916e-04
# Epoch 52/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 3.5830 - accuracy: 0.1883
# Epoch 52: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.5831 - accuracy: 0.1883 - val_loss: 3.5705 - val_accuracy: 0.1968 - lr: 8.7694e-04
# Epoch 53/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 3.5749 - accuracy: 0.1861
# Epoch 53: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.5745 - accuracy: 0.1864 - val_loss: 3.6799 - val_accuracy: 0.1793 - lr: 8.7473e-04
# Epoch 54/200
# 1243/1250 [============================>.] - ETA: 0s - loss: 3.9132 - accuracy: 0.1538
# Epoch 54: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.9124 - accuracy: 0.1540 - val_loss: 3.8152 - val_accuracy: 0.1635 - lr: 8.7252e-04
# Epoch 55/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 3.6864 - accuracy: 0.1782
# Epoch 55: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 5ms/step - loss: 3.6867 - accuracy: 0.1781 - val_loss: 3.5908 - val_accuracy: 0.1936 - lr: 8.7032e-04
# Epoch 56/200
# 1240/1250 [============================>.] - ETA: 0s - loss: 3.6161 - accuracy: 0.1840
# Epoch 56: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 8s 6ms/step - loss: 3.6162 - accuracy: 0.1841 - val_loss: 3.7609 - val_accuracy: 0.1681 - lr: 8.6813e-04
# Epoch 57/200
# 1245/1250 [============================>.] - ETA: 0s - loss: 3.6181 - accuracy: 0.1837
# Epoch 57: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.6186 - accuracy: 0.1836 - val_loss: 3.5987 - val_accuracy: 0.1919 - lr: 8.6594e-04
# Epoch 58/200
# 1244/1250 [============================>.] - ETA: 0s - loss: 3.5904 - accuracy: 0.1859
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.0004318769497331232.
# Restoring model weights from the end of the best epoch: 38.
#
# Epoch 58: val_accuracy did not improve from 0.19850
# 1250/1250 [==============================] - 7s 6ms/step - loss: 3.5900 - accuracy: 0.1858 - val_loss: 3.6358 - val_accuracy: 0.1791 - lr: 8.6375e-04
# Epoch 58: early stopping
